# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_excel('housing.xlsx')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %%
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots.
# Please explain the distribution of the plot.

average_income = data['median_income'].mean()  # .mean() is used to calculate average value of the median_income column

print("Average of median_income :",average_income)

data.hist(bins=30,figsize=(20,15),color='orange') # Histogram helps us to see the distribution of a numerical values
plt.show()
# Out:
# Average of median_income : 3.8706710029069766

# %%
# 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

plt.hist(data.housing_median_age) # plots a histogram for housing_median_age
plt.xlabel('housing_median_age')  # naming the x-axis
plt.ylabel('frequency')  # naming the y-axis
plt.show()  # gives the plot of the selected column

sns.kdeplot(data['housing_median_age'], shade=True) # using seaborn library we plot continuous probability density curve

# add appropriate labels and titles

plt.title("Distribution plot") # giving an appropriate title 

plt.xlabel("housing_median_age") # naming the x-axis

plt.ylabel("Density")  # naming the y-axis

plt.show()  # gives the plot of the selected column

# %%
# 3. Show with the help of visualization, how median_income and median_house_values are related?

plt.scatter(data['median_house_value'], data['median_income'], color="red", label="Automatic", marker="H", edgecolor="black")

# scatter plot shows us the relation or trend between two variables
# In this case House_value is directly related to Income

plt.xlabel("House Value")

plt.ylabel("Income")

plt.title("Relationship between House Value and House Income")

plt.show()

# %%
# 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

data.isnull().sum()  # isnull shows the null values present in the dataset
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df1 = data.dropna(subset=['total_bedrooms'])  # deletes null values from the dataset
df1.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df1  # after removing null values we have 20433 records
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

mean_value = data['total_bedrooms'].mean()  # calculates the mean value of total_bedrooms using .mean() method 
print("Mean of Total Bedrooms :",mean_value)

df2 = data.fillna({'total_bedrooms':mean_value})
# fills the missing values in the data with mean of total_bedrooms using .fillna() method
# Out:
# Mean of Total Bedrooms : 537.8705525375618

# %%
df2.loc[290:350]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                  47         1256      537.870553
# 291    -122.16     37.77                  48          977      194.000000
# 292    -122.16     37.77                  45         2324      397.000000
# 293    -122.16     37.77                  39         1583      349.000000
# 294    -122.17     37.77                  39         1612      342.000000
# ..         ...       ...                 ...          ...             ...
# 346    -122.17     37.76                  33         1280      307.000000
# 347    -122.17     37.75                  43         1587      320.000000
# 348    -122.17     37.75                  41         1257      271.000000
# 349    -122.17     37.75                  44         1218      248.000000
# 350    -122.17     37.75                  48         1751      390.000000
#
#      population  households  median_income  median_house_value ocean_proximity
# ...

# %%
# 6. Write a programming construct (create a user defined function) to 
# calculate the median value of the data set wherever required.

import re
import statistics

# Sample dataset
dataset = {
    "column_1": data['longitude'],"column_2": data['latitude'],"column_3": data['housing_median_age'],
    "column_4": data['total_rooms'],"column_5": data['total_bedrooms'],"column_6": data['population'],
    "column_7": data['households'],"column_8": data['median_income'],"column_9": data['median_house_value']
}

def calculate_median(data):  # defining a function calculate_median
    return statistics.median(data)

# Iterate through columns in the dataset
for column_name, column_data in dataset.items():
    # Check if the column name contains a digit using regex
    if re.search(r'\d', column_name):  # checks if there is atleast one digit in the column
        median = calculate_median(column_data)
        print((column_name,median))
# Out:
# ('column_1', -118.49)
# ('column_2', 34.26)
# ('column_3', 29.0)
# ('column_4', 2127.0)
# ('column_5', 322.5)
# ('column_6', 1166.0)
# ('column_7', 409.0)
# ('column_8', 3.5347999999999997)
# ('column_9', 179700.0)

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# 7. Plot latitude versus longitude and explain your observations.

sns.scatterplot(x='latitude',y='longitude',data=data)  # observing the relation between latitude and longitude

# add appropriate labels and titles

plt.xlabel("Longitude")

plt.ylabel("Latitude")

plt.title("Latitude VS longitude")

plt.show()

# %%
# 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

data_set = data.loc[data['ocean_proximity']=='NEAR OCEAN'] 

# .loc method allow us to return the specified data from the dataset

data_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %%
# 9. Find the mean and median of the median income for the data set created in question 8.

mean_value = data_set['median_income'].mean() # mean is calculated for the avove data_set
print("Mean of median_income :",mean_value)

median_value = data_set['median_income'].median()  # median is calculated for the above data_set
print("Median of median_income :",median_value)
# Out:
# Mean of median_income : 4.0057848006019565
# Median of median_income : 3.64705

# %%
# 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. 
# If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

initial_count = 0  # initializing count value to zero

count_of_bedrooms = [
              (data['total_bedrooms'] <=10),
              (data['total_bedrooms'] >=11) & (data['total_bedrooms'] <=1000),
              (data['total_bedrooms'] > 1000)
             ]    

# list of conditions are provided for the given dataset

sizes_of_bedrooms = ['small','medium','large']  # categorizing the sizes

data['total_bedroom_size'] = np.select(count_of_bedrooms,sizes_of_bedrooms)  # new column is created

# selects the category size for given count and assigns that value for each row in a column

data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
